# %%
import pandas as pd
import numpy as np

# %%
online_sales = pd.read_csv("C:/Users/subha/Downloads/Online_Sales.csv")
online_sales
# Out:
#        CustomerID  Transaction_ID  Transaction_Date     Product_SKU  \
# 0           17850           16679          20190101  GGOENEBJ079499
# 1           17850           16680          20190101  GGOENEBJ079499
# 2           17850           16681          20190101  GGOEGFKQ020399
# 3           17850           16682          20190101  GGOEGAAB010516
# 4           17850           16682          20190101  GGOEGBJL013999
# ...           ...             ...               ...             ...
# 52919       14410           48493          20191231  GGOENEBB078899
# 52920       14410           48494          20191231  GGOEGAEB091117
# 52921       14410           48495          20191231  GGOENEBQ084699
# 52922       14600           48496          20191231  GGOENEBQ079199
# 52923       14600           48497          20191231  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
online_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  int64
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 4.0+ MB

# %%
customer_sales = pd.read_excel("C:/Users/subha/Downloads/CustomersData.xlsx")
customer_sales
# Out:
#       CustomerID Gender    Location  Tenure_Months
# 0          17850      M     Chicago             12
# 1          13047      M  California             43
# 2          12583      M     Chicago             33
# 3          13748      F  California             30
# 4          15100      M  California             49
# ...          ...    ...         ...            ...
# 1463       14438      F    New York             41
# 1464       12956      F     Chicago             48
# 1465       15781      M  New Jersey             19
# 1466       14410      F    New York             45
# 1467       14600      F  California              7
#
# [1468 rows x 4 columns]

# %%
customer_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1468 entries, 0 to 1467
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     1468 non-null   int64
#  1   Gender         1468 non-null   object
#  2   Location       1468 non-null   object
#  3   Tenure_Months  1468 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.0+ KB

# %%
discount_coupon = pd.read_csv("C:/Users/subha/Downloads/Discount_Coupon.csv")
discount_coupon
# Out:
#     Month      Product_Category Coupon_Code  Discount_pct
# 0     Jan               Apparel      SALE10            10
# 1     Feb               Apparel      SALE20            20
# 2     Mar               Apparel      SALE30            30
# 3     Jan              Nest-USA      ELEC10            10
# 4     Feb              Nest-USA      ELEC20            20
# ..    ...                   ...         ...           ...
# 199   Nov  Notebooks & Journals        NJ20            20
# 200   Dec  Notebooks & Journals        NJ30            30
# 201   Oct               Android       AND10            10
# 202   Nov               Android       AND20            20
# 203   Dec               Android       AND30            30
#
# [204 rows x 4 columns]

# %%
discount_coupon["Month"] = pd.to_datetime(discount_coupon["Month"],format='%b')
discount_coupon["Month"] = discount_coupon["Month"].apply(lambda x:x.month)

# %%
discount_coupon.rename(columns = {"Month":"month_number"},inplace = True)

# %%
discount_coupon
# Out:
#      month_number      Product_Category Coupon_Code  Discount_pct
# 0               1               Apparel      SALE10            10
# 1               2               Apparel      SALE20            20
# 2               3               Apparel      SALE30            30
# 3               1              Nest-USA      ELEC10            10
# 4               2              Nest-USA      ELEC20            20
# ..            ...                   ...         ...           ...
# 199            11  Notebooks & Journals        NJ20            20
# 200            12  Notebooks & Journals        NJ30            30
# 201            10               Android       AND10            10
# 202            11               Android       AND20            20
# 203            12               Android       AND30            30
#
# [204 rows x 4 columns]

# %%
discount_coupon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month_number      204 non-null    int64
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 6.5+ KB

# %%
discount_coupon.Product_Category.value_counts()
# Out:
# Product_Category
# Apparel                 12
# Waze                    12
# Notebooks & Journals    12
# Gift Cards              12
# Accessories             12
# Housewares              12
# Nest-Canada             12
# Bottles                 12
# Nest                    12
# Nest-USA                12
# Headgear                12
# Notebooks               12
# Bags                    12
# Lifestyle               12
# Drinkware               12
# Office                  12
# Android                 12
# Name: count, dtype: int64

# %%
discount_coupon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month_number      204 non-null    int64
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 6.5+ KB

# %%
marketing_spend = pd.read_csv("C:/Users/subha/Downloads/Marketing_Spend.csv")
marketing_spend
# Out:
#            Date  Offline_Spend  Online_Spend
# 0    01-01-2019           4500       2424.50
# 1    01-02-2019           4500       3480.36
# 2    01-03-2019           4500       1576.38
# 3    01-04-2019           4500       2928.55
# 4    01-05-2019           4500       4055.30
# ..          ...            ...           ...
# 360  12/27/2019           4000       3396.87
# 361  12/28/2019           4000       3246.84
# 362  12/29/2019           4000       2546.58
# 363  12/30/2019           4000        674.31
# 364  12/31/2019           4000       2058.75
#
# [365 rows x 3 columns]

# %%
marketing_spend.rename(columns = {"Date":"Marketing_Date"},inplace=True)

# %%
marketing_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Marketing_Date  365 non-null    object
#  1   Offline_Spend   365 non-null    int64
#  2   Online_Spend    365 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
tax_amount = pd.read_excel("C:/Users/subha/Downloads/Tax_amount.xlsx")
tax_amount
# Out:
#         Product_Category   GST
# 0               Nest-USA  0.10
# 1                 Office  0.10
# 2                Apparel  0.18
# 3                   Bags  0.18
# 4              Drinkware  0.18
# 5              Lifestyle  0.18
# 6   Notebooks & Journals  0.05
# 7               Headgear  0.05
# 8                   Waze  0.18
# 9                    Fun  0.18
# 10           Nest-Canada  0.10
# 11             Backpacks  0.10
# 12                Google  0.10
# 13               Bottles  0.05
# 14            Gift Cards  0.05
# 15             More Bags  0.18
# 16            Housewares  0.12
# 17               Android  0.10
# 18           Accessories  0.10
# 19                  Nest  0.05

# %%
tax_amount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  20 non-null     object
#  1   GST               20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes

# %%
online_customer_sales = pd.merge(left=online_sales,right=customer_sales,on="CustomerID")
online_customer_sales
# Out:
#        CustomerID  Transaction_ID  Transaction_Date     Product_SKU  \
# 0           17850           16679          20190101  GGOENEBJ079499
# 1           17850           16680          20190101  GGOENEBJ079499
# 2           17850           16681          20190101  GGOEGFKQ020399
# 3           17850           16682          20190101  GGOEGAAB010516
# 4           17850           16682          20190101  GGOEGBJL013999
# ...           ...             ...               ...             ...
# 52919       14410           48493          20191231  GGOENEBB078899
# 52920       14410           48494          20191231  GGOEGAEB091117
# 52921       14410           48495          20191231  GGOENEBQ084699
# 52922       14600           48496          20191231  GGOENEBQ079199
# 52923       14600           48497          20191231  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
online_customer_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  int64
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Gender               52924 non-null  object
#  11  Location             52924 non-null  object
#  12  Tenure_Months        52924 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 5.2+ MB

# %%
online_customer_tax = pd.merge(left=online_customer_sales,right=tax_amount,on='Product_Category')
online_customer_tax
# Out:
#        CustomerID  Transaction_ID  Transaction_Date     Product_SKU  \
# 0           17850           16679          20190101  GGOENEBJ079499
# 1           17850           16680          20190101  GGOENEBJ079499
# 2           17850           16681          20190101  GGOEGFKQ020399
# 3           17850           16682          20190101  GGOEGAAB010516
# 4           17850           16682          20190101  GGOEGBJL013999
# ...           ...             ...               ...             ...
# 52919       14410           48493          20191231  GGOENEBB078899
# 52920       14410           48494          20191231  GGOEGAEB091117
# 52921       14410           48495          20191231  GGOENEBQ084699
# 52922       14600           48496          20191231  GGOENEBQ079199
# 52923       14600           48497          20191231  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
online_customer_tax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  int64
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Gender               52924 non-null  object
#  11  Location             52924 non-null  object
#  12  Tenure_Months        52924 non-null  int64
#  13  GST                  52924 non-null  float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 5.7+ MB

# %%
online_customer_tax
# Out:
#        CustomerID  Transaction_ID  Transaction_Date     Product_SKU  \
# 0           17850           16679          20190101  GGOENEBJ079499
# 1           17850           16680          20190101  GGOENEBJ079499
# 2           17850           16681          20190101  GGOEGFKQ020399
# 3           17850           16682          20190101  GGOEGAAB010516
# 4           17850           16682          20190101  GGOEGBJL013999
# ...           ...             ...               ...             ...
# 52919       14410           48493          20191231  GGOENEBB078899
# 52920       14410           48494          20191231  GGOEGAEB091117
# 52921       14410           48495          20191231  GGOENEBQ084699
# 52922       14600           48496          20191231  GGOENEBQ079199
# 52923       14600           48497          20191231  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
#converting to date and time variable
online_customer_tax["Transaction_Date"] = pd.to_datetime(online_customer_tax["Transaction_Date"], format='%Y%m%d')

# %%
online_customer_tax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Gender               52924 non-null  object
#  11  Location             52924 non-null  object
#  12  Tenure_Months        52924 non-null  int64
#  13  GST                  52924 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(6)
# ...

# %%
online_customer_tax
# Out:
#        CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0           17850           16679       2019-01-01  GGOENEBJ079499
# 1           17850           16680       2019-01-01  GGOENEBJ079499
# 2           17850           16681       2019-01-01  GGOEGFKQ020399
# 3           17850           16682       2019-01-01  GGOEGAAB010516
# 4           17850           16682       2019-01-01  GGOEGBJL013999
# ...           ...             ...              ...             ...
# 52919       14410           48493       2019-12-31  GGOENEBB078899
# 52920       14410           48494       2019-12-31  GGOEGAEB091117
# 52921       14410           48495       2019-12-31  GGOENEBQ084699
# 52922       14600           48496       2019-12-31  GGOENEBQ079199
# 52923       14600           48497       2019-12-31  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
#extracting month
online_customer_tax["Transaction_Date_Month"]=online_customer_tax["Transaction_Date"].dt.to_period('M')

# %%
online_customer_tax
# Out:
#        CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0           17850           16679       2019-01-01  GGOENEBJ079499
# 1           17850           16680       2019-01-01  GGOENEBJ079499
# 2           17850           16681       2019-01-01  GGOEGFKQ020399
# 3           17850           16682       2019-01-01  GGOEGAAB010516
# 4           17850           16682       2019-01-01  GGOEGBJL013999
# ...           ...             ...              ...             ...
# 52919       14410           48493       2019-12-31  GGOENEBB078899
# 52920       14410           48494       2019-12-31  GGOEGAEB091117
# 52921       14410           48495       2019-12-31  GGOENEBQ084699
# 52922       14600           48496       2019-12-31  GGOENEBQ079199
# 52923       14600           48497       2019-12-31  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
online_customer_tax[online_customer_tax['CustomerID'].duplicated() == True]
# Out:
#        CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 1           17850           16680       2019-01-01  GGOENEBJ079499
# 2           17850           16681       2019-01-01  GGOEGFKQ020399
# 3           17850           16682       2019-01-01  GGOEGAAB010516
# 4           17850           16682       2019-01-01  GGOEGBJL013999
# 5           17850           16682       2019-01-01  GGOEGBMJ013399
# ...           ...             ...              ...             ...
# 52918       14410           48492       2019-12-31  GGOENEBQ086799
# 52919       14410           48493       2019-12-31  GGOENEBB078899
# 52920       14410           48494       2019-12-31  GGOEGAEB091117
# 52921       14410           48495       2019-12-31  GGOENEBQ084699
# 52923       14600           48497       2019-12-31  GGOENEBQ079099
#
#                                      Product_Description Product_Category  \
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# ...

# %%
online_customer_tax_min=online_customer_tax.groupby(["CustomerID"])[["Transaction_Date_Month"]].min()
online_customer_tax_min
# Out:
#            Transaction_Date_Month
# CustomerID
# 12346                     2019-09
# 12347                     2019-03
# 12348                     2019-06
# 12350                     2019-12
# 12356                     2019-09
# ...                           ...
# 18259                     2019-04
# 18260                     2019-06
# 18269                     2019-04
# 18277                     2019-10
# 18283                     2019-07
#
# [1468 rows x 1 columns]
